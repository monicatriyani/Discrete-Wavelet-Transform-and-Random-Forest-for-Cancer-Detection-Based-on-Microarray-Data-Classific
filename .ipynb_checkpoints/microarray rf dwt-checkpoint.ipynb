# %% [markdown]
# # Microarray : Random Forest and DWT

# %% [markdown]
# ### Import Packages and Dataset
#
# ***Packages***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import math
from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from scipy.spatial.distance import cdist
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import KFold, LeaveOneOut
from sklearn.metrics import accuracy_score

from ReliefF import ReliefF
from sklearn.decomposition import PCA
from sklearn.feature_selection import mutual_info_classif
from yellowbrick.features.pca import PCADecomposition
import pywt
# from skrebate import ReliefF

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ***Dataset***

# %% [markdown]
# - colon tumor cancer

# %%
data = pd.read_csv("data/colonTumor.csv")
data_length = data.shape[1]
data_length
# Out:
# 2001

# %%
column = []
for i in range(data_length):
    column.append("atribut"+str(i))

# %%
data_colon = pd.read_csv("data/colonTumor.csv", header=None, names=column)
data_colon.head()
# Out:
#     atribut0   atribut1   atribut2   atribut3   atribut4   atribut5  \
# 0  8589.4163  5468.2409  4263.4075  4064.9357  1997.8929  5282.3250
# 1  9164.2537  6719.5295  4883.4487  3718.1589  2015.2214  5569.9071
# 2  3825.7050  6970.3614  5369.9688  4705.6500  1166.5536  1572.1679
# 3  6246.4487  7823.5341  5955.8350  3975.5643  2002.6131  2130.5429
# 4  3230.3287  3694.4500  3400.7400  3463.5857  2181.4202  2922.7821
#
#     atribut6   atribut7   atribut8   atribut9  ...  atribut1991  atribut1992  \
# 0  2169.7200  2773.4212  7526.3862  4607.6762  ...     67.56125    259.91250
# 1  3849.0588  2793.3875  7017.7338  4802.2524  ...     92.23875     96.27625
# 2  1325.4025  1472.2587  3296.9512  2786.5821  ...     82.71500     31.10250
# 3  1531.1425  1714.6312  3869.7850  4989.4071  ...     41.68375      5.92500
# 4  2069.2463  2948.5750  3303.3712  3109.4131  ...     76.60375    161.35000
#
#    atribut1993  atribut1994  atribut1995  atribut1996  atribut1997  \
# ...

# %%
data_colon = data_colon.rename(columns={'atribut2000': 'status'})
data_colon.head()
# Out:
#     atribut0   atribut1   atribut2   atribut3   atribut4   atribut5  \
# 0  8589.4163  5468.2409  4263.4075  4064.9357  1997.8929  5282.3250
# 1  9164.2537  6719.5295  4883.4487  3718.1589  2015.2214  5569.9071
# 2  3825.7050  6970.3614  5369.9688  4705.6500  1166.5536  1572.1679
# 3  6246.4487  7823.5341  5955.8350  3975.5643  2002.6131  2130.5429
# 4  3230.3287  3694.4500  3400.7400  3463.5857  2181.4202  2922.7821
#
#     atribut6   atribut7   atribut8   atribut9  ...  atribut1991  atribut1992  \
# 0  2169.7200  2773.4212  7526.3862  4607.6762  ...     67.56125    259.91250
# 1  3849.0588  2793.3875  7017.7338  4802.2524  ...     92.23875     96.27625
# 2  1325.4025  1472.2587  3296.9512  2786.5821  ...     82.71500     31.10250
# 3  1531.1425  1714.6312  3869.7850  4989.4071  ...     41.68375      5.92500
# 4  2069.2463  2948.5750  3303.3712  3109.4131  ...     76.60375    161.35000
#
#    atribut1993  atribut1994  atribut1995  atribut1996  atribut1997  \
# ...

# %%
data_colon.loc[data_colon['status'] == 'negative', ['status']] = 0
data_colon.loc[data_colon['status'] == 'positive', ['status']] = 1
data_colon.head()
# Out:
#     atribut0   atribut1   atribut2   atribut3   atribut4   atribut5  \
# 0  8589.4163  5468.2409  4263.4075  4064.9357  1997.8929  5282.3250
# 1  9164.2537  6719.5295  4883.4487  3718.1589  2015.2214  5569.9071
# 2  3825.7050  6970.3614  5369.9688  4705.6500  1166.5536  1572.1679
# 3  6246.4487  7823.5341  5955.8350  3975.5643  2002.6131  2130.5429
# 4  3230.3287  3694.4500  3400.7400  3463.5857  2181.4202  2922.7821
#
#     atribut6   atribut7   atribut8   atribut9  ...  atribut1991  atribut1992  \
# 0  2169.7200  2773.4212  7526.3862  4607.6762  ...     67.56125    259.91250
# 1  3849.0588  2793.3875  7017.7338  4802.2524  ...     92.23875     96.27625
# 2  1325.4025  1472.2587  3296.9512  2786.5821  ...     82.71500     31.10250
# 3  1531.1425  1714.6312  3869.7850  4989.4071  ...     41.68375      5.92500
# 4  2069.2463  2948.5750  3303.3712  3109.4131  ...     76.60375    161.35000
#
#    atribut1993  atribut1994  atribut1995  atribut1996  atribut1997  \
# ...

# %%
data_colon = data_colon.apply(pd.to_numeric)

# %% [markdown]
# - lung cancer

# %%
data = pd.read_csv("data/lungCancer_train.csv")
data_length = data.shape[1]
data_length
# Out:
# 12534

# %%
column = []
for i in range(data_length):
    column.append("atribut"+str(i))

# %%
data_lung = pd.read_csv("data/lungCancer_train.csv", header=None, names=column)
data_lung = data_lung.append(pd.read_csv("data/lungCancer_test.csv", header=None, names=column))
data_lung.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0     199.1      38.7      -1.0     -55.9       4.5    1042.5     -12.0
# 1     188.5      82.0     -10.1      30.5      -6.6     877.1      71.0
# 2     284.1      35.6     -19.6    -111.2     -25.0     993.4      11.3
# 3     204.5      20.4       9.4     -99.5     -10.1     273.9      22.8
# 4     213.1      98.3      31.4      46.1      75.0    1568.6      17.8
#
#    atribut7  atribut8  atribut9  ...  atribut12524  atribut12525  \
# 0     783.2     320.9    1384.8  ...           8.6          12.7
# 1     309.9    2347.2    1017.6  ...          14.5         -32.3
# 2     594.1     485.4     843.9  ...          13.2          59.0
# 3     713.3     250.0    1212.2  ...          18.9          18.7
# 4     769.2    4540.3     947.6  ...          14.7          68.9
#
#    atribut12526  atribut12527  atribut12528  atribut12529  atribut12530  \
# ...

# %%
data_lung = data_lung.rename(columns={'atribut12533': 'status'})
data_lung.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0     199.1      38.7      -1.0     -55.9       4.5    1042.5     -12.0
# 1     188.5      82.0     -10.1      30.5      -6.6     877.1      71.0
# 2     284.1      35.6     -19.6    -111.2     -25.0     993.4      11.3
# 3     204.5      20.4       9.4     -99.5     -10.1     273.9      22.8
# 4     213.1      98.3      31.4      46.1      75.0    1568.6      17.8
#
#    atribut7  atribut8  atribut9  ...  atribut12524  atribut12525  \
# 0     783.2     320.9    1384.8  ...           8.6          12.7
# 1     309.9    2347.2    1017.6  ...          14.5         -32.3
# 2     594.1     485.4     843.9  ...          13.2          59.0
# 3     713.3     250.0    1212.2  ...          18.9          18.7
# 4     769.2    4540.3     947.6  ...          14.7          68.9
#
#    atribut12526  atribut12527  atribut12528  atribut12529  atribut12530  \
# ...

# %%
data_lung.loc[data_lung['status'] == 'Mesothelioma', ['status']] = 0
data_lung.loc[data_lung['status'] == 'ADCA', ['status']] = 1
data_lung.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0     199.1      38.7      -1.0     -55.9       4.5    1042.5     -12.0
# 1     188.5      82.0     -10.1      30.5      -6.6     877.1      71.0
# 2     284.1      35.6     -19.6    -111.2     -25.0     993.4      11.3
# 3     204.5      20.4       9.4     -99.5     -10.1     273.9      22.8
# 4     213.1      98.3      31.4      46.1      75.0    1568.6      17.8
#
#    atribut7  atribut8  atribut9  ...  atribut12524  atribut12525  \
# 0     783.2     320.9    1384.8  ...           8.6          12.7
# 1     309.9    2347.2    1017.6  ...          14.5         -32.3
# 2     594.1     485.4     843.9  ...          13.2          59.0
# 3     713.3     250.0    1212.2  ...          18.9          18.7
# 4     769.2    4540.3     947.6  ...          14.7          68.9
#
#    atribut12526  atribut12527  atribut12528  atribut12529  atribut12530  \
# ...

# %%
data_lung = data_lung.apply(pd.to_numeric)

# %% [markdown]
# - Central Nervous System

# %%
data = pd.read_csv("data/centralNervousSystem_outcome.csv")
data_length = data.shape[1]
data_length
# Out:
# 7130

# %%
column = []
for i in range(data_length):
    column.append("atribut"+str(i))

# %%
data_cns = pd.read_csv("data/centralNervousSystem_outcome.csv", header=None, names=column)
data_cns.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0       -60      -109        45        22         7       -61      -211
# 1      -159      -113       -62       -16      -160      -395        97
# 2      -119       -31         4       -11      -197      -541      -277
# 3        41         9      -256       370      -302      -680       254
# 4      -165       -57       171       216      -692      -381       762
#
#    atribut7  atribut8  atribut9  ...  atribut7120  atribut7121  atribut7122  \
# 0      -102       -20        98  ...         1082          -12           44
# 1      -157        15        -8  ...         1295         -677         -452
# 2      -166        17       392  ...          592           55           88
# 3        31       186       358  ...          433           71         -237
# 4        -6        44       216  ...         2160         -120          -82
#
#    atribut7123  atribut7124  atribut7125  atribut7126  atribut7127  \
# ...

# %%
data_cns = data_cns.rename(columns={'atribut7129': 'status'})
data_cns.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0       -60      -109        45        22         7       -61      -211
# 1      -159      -113       -62       -16      -160      -395        97
# 2      -119       -31         4       -11      -197      -541      -277
# 3        41         9      -256       370      -302      -680       254
# 4      -165       -57       171       216      -692      -381       762
#
#    atribut7  atribut8  atribut9  ...  atribut7120  atribut7121  atribut7122  \
# 0      -102       -20        98  ...         1082          -12           44
# 1      -157        15        -8  ...         1295         -677         -452
# 2      -166        17       392  ...          592           55           88
# 3        31       186       358  ...          433           71         -237
# 4        -6        44       216  ...         2160         -120          -82
#
#    atribut7123  atribut7124  atribut7125  atribut7126  atribut7127  \
# ...

# %%
data_cns.loc[data_cns['status'] == 'Class0', ['status']] = 0
data_cns.loc[data_cns['status'] == 'Class1', ['status']] = 1
data_cns.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0       -60      -109        45        22         7       -61      -211
# 1      -159      -113       -62       -16      -160      -395        97
# 2      -119       -31         4       -11      -197      -541      -277
# 3        41         9      -256       370      -302      -680       254
# 4      -165       -57       171       216      -692      -381       762
#
#    atribut7  atribut8  atribut9  ...  atribut7120  atribut7121  atribut7122  \
# 0      -102       -20        98  ...         1082          -12           44
# 1      -157        15        -8  ...         1295         -677         -452
# 2      -166        17       392  ...          592           55           88
# 3        31       186       358  ...          433           71         -237
# 4        -6        44       216  ...         2160         -120          -82
#
#    atribut7123  atribut7124  atribut7125  atribut7126  atribut7127  \
# ...

# %%
data_cns = data_cns.apply(pd.to_numeric)

# %% [markdown]
# - breast cancer

# %%
data = pd.read_csv("data/breastCancer_train.csv")
data_length = data.shape[1]
data_length
# Out:
# 24482

# %%
column = []
for i in range(data_length):
    column.append("atribut"+str(i))

# %%
data_breast = pd.read_csv("data/breastCancer_train.csv", header=None, names=column)
data_breast = data_breast.append(pd.read_csv("data/breastCancer_test.csv", header=None, names=column))
data_breast.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0    -0.299     0.093    -0.215    -0.566    -0.596    -0.195     0.039
# 1    -0.081     0.009    -0.091    -0.518    -0.502    -0.149     0.098
# 2    -0.125     0.070    -0.006    -0.575    -0.585    -0.183     0.102
# 3    -0.270     0.123     0.056    -0.499    -0.402    -0.099    -0.145
# 4    -0.141     0.025    -0.031    -0.465    -0.533    -0.065     0.101
#
#    atribut7  atribut8  atribut9  ...  atribut24472  atribut24473  \
# 0    -0.409    -0.352     0.066  ...        -0.960        -0.211
# 1    -0.090     0.138     0.061  ...        -0.531        -0.020
# 2     0.023    -0.350    -0.005  ...        -0.883        -0.159
# 3    -0.103     0.181     0.236  ...        -0.044        -0.096
# 4    -0.008    -0.019     0.026  ...         0.280        -0.088
#
#    atribut24474  atribut24475  atribut24476  atribut24477  atribut24478  \
# ...

# %%
data_breast = data_breast.rename(columns={'atribut24481': 'status'})
data_breast.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0    -0.299     0.093    -0.215    -0.566    -0.596    -0.195     0.039
# 1    -0.081     0.009    -0.091    -0.518    -0.502    -0.149     0.098
# 2    -0.125     0.070    -0.006    -0.575    -0.585    -0.183     0.102
# 3    -0.270     0.123     0.056    -0.499    -0.402    -0.099    -0.145
# 4    -0.141     0.025    -0.031    -0.465    -0.533    -0.065     0.101
#
#    atribut7  atribut8  atribut9  ...  atribut24472  atribut24473  \
# 0    -0.409    -0.352     0.066  ...        -0.960        -0.211
# 1    -0.090     0.138     0.061  ...        -0.531        -0.020
# 2     0.023    -0.350    -0.005  ...        -0.883        -0.159
# 3    -0.103     0.181     0.236  ...        -0.044        -0.096
# 4    -0.008    -0.019     0.026  ...         0.280        -0.088
#
#    atribut24474  atribut24475  atribut24476  atribut24477  atribut24478  \
# ...

# %%
data_breast.loc[data_breast['status'] == 'non-relapse', ['status']] = 0
data_breast.loc[data_breast['status'] == 'relapse', ['status']] = 1
data_breast.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0    -0.299     0.093    -0.215    -0.566    -0.596    -0.195     0.039
# 1    -0.081     0.009    -0.091    -0.518    -0.502    -0.149     0.098
# 2    -0.125     0.070    -0.006    -0.575    -0.585    -0.183     0.102
# 3    -0.270     0.123     0.056    -0.499    -0.402    -0.099    -0.145
# 4    -0.141     0.025    -0.031    -0.465    -0.533    -0.065     0.101
#
#    atribut7  atribut8  atribut9  ...  atribut24472  atribut24473  \
# 0    -0.409    -0.352     0.066  ...        -0.960        -0.211
# 1    -0.090     0.138     0.061  ...        -0.531        -0.020
# 2     0.023    -0.350    -0.005  ...        -0.883        -0.159
# 3    -0.103     0.181     0.236  ...        -0.044        -0.096
# 4    -0.008    -0.019     0.026  ...         0.280        -0.088
#
#    atribut24474  atribut24475  atribut24476  atribut24477  atribut24478  \
# ...

# %%
data_breast = data_breast.apply(pd.to_numeric)

# %% [markdown]
# - ovarian cancer

# %%
data = pd.read_csv("data/ovarian_61902.csv")
data_length = data.shape[1]
data_length
# Out:
# 15155

# %%
column = []
for i in range(data_length):
    column.append("atribut"+str(i))

# %%
data_ovarian = pd.read_csv("data/ovarian_61902.csv", header=None, names=column)
data_ovarian.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0  0.494626  0.263735  0.321841  0.220934  0.297622  0.316458  0.154763
# 1  0.258063  0.406593  0.321841  0.069771  0.333335  0.354432  0.321431
# 2  0.537636  0.032966  0.321841  0.209307  0.404762  0.113927  0.369049
# 3  0.000000  0.395605  0.310347  0.197673  0.404762  0.455701  0.416666
# 4  0.526884  0.395605  0.367817  0.383719  0.488099  0.392405  0.238094
#
#    atribut7  atribut8  atribut9  ...  atribut15145  atribut15146  \
# 0  0.223685  0.304346  0.241757  ...      0.483622      0.449296
# 1  0.144740  0.260869  0.142853  ...      0.631765      0.619718
# 2  0.223685  0.536231  0.131865  ...      0.038462      0.035918
# 3  0.210527  0.420292  0.274723  ...      0.497864      0.486621
# 4  0.500000  0.362316  0.274723  ...      0.267096      0.251408
#
#    atribut15147  atribut15148  atribut15149  atribut15150  atribut15151  \
# ...

# %%
data_ovarian = data_ovarian.rename(columns={'atribut15154': 'status'})
data_ovarian.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0  0.494626  0.263735  0.321841  0.220934  0.297622  0.316458  0.154763
# 1  0.258063  0.406593  0.321841  0.069771  0.333335  0.354432  0.321431
# 2  0.537636  0.032966  0.321841  0.209307  0.404762  0.113927  0.369049
# 3  0.000000  0.395605  0.310347  0.197673  0.404762  0.455701  0.416666
# 4  0.526884  0.395605  0.367817  0.383719  0.488099  0.392405  0.238094
#
#    atribut7  atribut8  atribut9  ...  atribut15145  atribut15146  \
# 0  0.223685  0.304346  0.241757  ...      0.483622      0.449296
# 1  0.144740  0.260869  0.142853  ...      0.631765      0.619718
# 2  0.223685  0.536231  0.131865  ...      0.038462      0.035918
# 3  0.210527  0.420292  0.274723  ...      0.497864      0.486621
# 4  0.500000  0.362316  0.274723  ...      0.267096      0.251408
#
#    atribut15147  atribut15148  atribut15149  atribut15150  atribut15151  \
# ...

# %%
data_ovarian.loc[data_ovarian['status'] == 'Normal', ['status']] = 0
data_ovarian.loc[data_ovarian['status'] == 'Cancer', ['status']] = 1
data_ovarian.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0  0.494626  0.263735  0.321841  0.220934  0.297622  0.316458  0.154763
# 1  0.258063  0.406593  0.321841  0.069771  0.333335  0.354432  0.321431
# 2  0.537636  0.032966  0.321841  0.209307  0.404762  0.113927  0.369049
# 3  0.000000  0.395605  0.310347  0.197673  0.404762  0.455701  0.416666
# 4  0.526884  0.395605  0.367817  0.383719  0.488099  0.392405  0.238094
#
#    atribut7  atribut8  atribut9  ...  atribut15145  atribut15146  \
# 0  0.223685  0.304346  0.241757  ...      0.483622      0.449296
# 1  0.144740  0.260869  0.142853  ...      0.631765      0.619718
# 2  0.223685  0.536231  0.131865  ...      0.038462      0.035918
# 3  0.210527  0.420292  0.274723  ...      0.497864      0.486621
# 4  0.500000  0.362316  0.274723  ...      0.267096      0.251408
#
#    atribut15147  atribut15148  atribut15149  atribut15150  atribut15151  \
# ...

# %%
data_ovarian = data_ovarian.apply(pd.to_numeric)

# %% [markdown]
# - prostate cancer

# %%
data = pd.read_csv("data/prostate_outcome.csv")
data_length = data.shape[1]
data_length
# Out:
# 12601

# %%
column = []
for i in range(data_length):
    column.append("atribut"+str(i))

# %%
data_prostate = pd.read_csv("data/prostate_outcome.csv", header=None, names=column)
data_prostate.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0      -6.0       0.0      -1.0       3.0      -5.0      -9.0       0.0
# 1       0.0       3.0       1.0       4.0       1.0     -10.0      -1.0
# 2      -8.0      12.0      12.0       8.0      -7.0     -31.0     -10.0
# 3       2.0      -2.0      -2.0       4.0       1.0      -2.0       0.0
# 4      10.0      12.0      23.0      71.0      -1.0     -71.0     -50.0
#
#    atribut7  atribut8  atribut9  ...  atribut12591  atribut12592  \
# 0       2.0      -7.0     -15.0  ...           8.0           3.0
# 1       8.0      -2.0     -11.0  ...          32.0           5.0
# 2      14.0     -32.0     -49.0  ...         -13.0          30.0
# 3      11.0      -3.0     -15.0  ...           8.0           5.0
# 4      67.0     -91.0    -108.0  ...         -76.0          13.0
#
#    atribut12593  atribut12594  atribut12595  atribut12596  atribut12597  \
# ...

# %%
data_prostate = data_prostate.rename(columns={'atribut12600': 'status'})
data_prostate.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0      -6.0       0.0      -1.0       3.0      -5.0      -9.0       0.0
# 1       0.0       3.0       1.0       4.0       1.0     -10.0      -1.0
# 2      -8.0      12.0      12.0       8.0      -7.0     -31.0     -10.0
# 3       2.0      -2.0      -2.0       4.0       1.0      -2.0       0.0
# 4      10.0      12.0      23.0      71.0      -1.0     -71.0     -50.0
#
#    atribut7  atribut8  atribut9  ...  atribut12591  atribut12592  \
# 0       2.0      -7.0     -15.0  ...           8.0           3.0
# 1       8.0      -2.0     -11.0  ...          32.0           5.0
# 2      14.0     -32.0     -49.0  ...         -13.0          30.0
# 3      11.0      -3.0     -15.0  ...           8.0           5.0
# 4      67.0     -91.0    -108.0  ...         -76.0          13.0
#
#    atribut12593  atribut12594  atribut12595  atribut12596  atribut12597  \
# ...

# %%
data_prostate.loc[data_prostate['status'] == 'Non-relapse', ['status']] = 0
data_prostate.loc[data_prostate['status'] == 'Relapse', ['status']] = 1
data_prostate.head()
# Out:
#    atribut0  atribut1  atribut2  atribut3  atribut4  atribut5  atribut6  \
# 0      -6.0       0.0      -1.0       3.0      -5.0      -9.0       0.0
# 1       0.0       3.0       1.0       4.0       1.0     -10.0      -1.0
# 2      -8.0      12.0      12.0       8.0      -7.0     -31.0     -10.0
# 3       2.0      -2.0      -2.0       4.0       1.0      -2.0       0.0
# 4      10.0      12.0      23.0      71.0      -1.0     -71.0     -50.0
#
#    atribut7  atribut8  atribut9  ...  atribut12591  atribut12592  \
# 0       2.0      -7.0     -15.0  ...           8.0           3.0
# 1       8.0      -2.0     -11.0  ...          32.0           5.0
# 2      14.0     -32.0     -49.0  ...         -13.0          30.0
# 3      11.0      -3.0     -15.0  ...           8.0           5.0
# 4      67.0     -91.0    -108.0  ...         -76.0          13.0
#
#    atribut12593  atribut12594  atribut12595  atribut12596  atribut12597  \
# ...

# %%
data_prostate = data_prostate.apply(pd.to_numeric)

# %% [markdown]
# ### Data Analytics

# %% [markdown]
# **perbandingan jumlah antar kelas**

# %% [markdown]
# - colon cancer

# %%
data_colon['status'].value_counts().plot(kind='bar', color="r")
plt.title("Perbandingan jumlah positive dan negative")
plt.xlabel('Status')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# - lung cancer

# %%
data_lung['status'].value_counts().plot(kind='bar', color="r")
plt.title("Perbandingan tiap kelas")
plt.xlabel('Status')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# - Central Nervous System

# %%
data_cns['status'].value_counts().plot(kind='bar', color="r")
plt.title("Perbandingan tiap kelas")
plt.xlabel('Status')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# - breast cancer

# %%
data_breast['status'].value_counts().plot(kind='bar', color="r")
plt.title("Perbandingan tiap kelas")
plt.xlabel('Status')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# - ovarian cancer

# %%
data_ovarian['status'].value_counts().plot(kind='bar', color="r")
plt.title("Perbandingan tiap kelas")
plt.xlabel('Status')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# - prostate cancer

# %%
data_prostate['status'].value_counts().plot(kind='bar', color="r")
plt.title("Perbandingan tiap kelas")
plt.xlabel('Status')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# ### Features Target Split

# %% [markdown]
# - colon cancer

# %%
X_colon = data_colon.drop(['status'],axis=1)
y_colon = data_colon['status']

# %%
X_colon.shape
# Out:
# (62, 2000)

# %% [markdown]
# - lung cancer

# %%
X_lung = data_lung.drop(['status'],axis=1)
y_lung = data_lung['status']

# %%
X_lung.shape
# Out:
# (181, 12533)

# %% [markdown]
# - Central Nervous System

# %%
X_cns = data_cns.drop(['status'],axis=1)
y_cns = data_cns['status']

# %%
X_cns.shape
# Out:
# (60, 7129)

# %% [markdown]
# - breast cancer

# %%
X_breast = data_breast.drop(['status'],axis=1)
y_breast = data_breast['status']

# %%
X_breast.shape
# Out:
# (97, 24481)

# %% [markdown]
# - ovarian cancer

# %%
X_ovarian = data_ovarian.drop(['status'],axis=1)
y_ovarian = data_ovarian['status']

# %%
X_ovarian.shape
# Out:
# (253, 15154)

# %% [markdown]
# - prostate cancer

# %%
X_prostate = data_prostate.drop(['status'],axis=1)
y_prostate = data_prostate['status']

# %%
X_prostate.shape
# Out:
# (21, 12600)

# %% [markdown]
# ### Normalisasi

# %%
def standard_scaler(X_train_, X_test_):
    scaler = StandardScaler()
    X_train_ = scaler.fit_transform(X_train_)
    X_test_ = scaler.transform(X_test_)
    return X_train_,X_test_

# %%
def minmax_scaler(X_train_, X_test_):
    scaler = MinMaxScaler()
    X_train_ = scaler.fit_transform(X_train_)
    X_test_ = scaler.transform(X_test_)
    return X_train_,X_test_

# %% [markdown]
# ### DWT

# %%
def dwt(X_train, X_test):
    train_coef = pywt.dwt(X_train, 'db4')
    #(cA, cD) = train_coef
    test_coef = pywt.dwt(X_test, 'db4')
    #(cA, cD) = 
    return train_coef, test_coef

# %%
def koef_train(train_coef):
    (cA, cD) = train_coef
    return (cA, cD)

def koef_test(test_coef):
    (cA, cD) = test_coef
    return (cA, cD)

# %% [markdown]
# ### Classification

# %%
model_rfg = RandomForestClassifier(criterion='gini', n_estimators=60)

# %%
X_colon_ = X_colon.values
y_colon_ = y_colon.values

X_lung_ = X_lung.values
y_lung_ = y_lung.values

X_cns_ = X_cns.values
y_cns_ = y_cns.values

X_breast_ = X_breast.values
y_breast_ = y_breast.values

X_ovarian_ = X_ovarian.values
y_ovarian_ = y_ovarian.values

X_prostate_ = X_prostate.values
y_prostate_ = y_prostate.values

# %% [markdown]
# **K-fold Cross Validation**

# %%
kf_colon = KFold(n_splits=8, random_state=20)
kf_colon.get_n_splits(X_colon_)
# Out:
# 8

# %%
kf_lung = KFold(n_splits=8, random_state=20)
kf_lung.get_n_splits(X_lung_)
# Out:
# 8

# %%
kf_cns = KFold(n_splits=8, random_state=20)
kf_cns.get_n_splits(X_cns_)
# Out:
# 8

# %%
kf_breast = KFold(n_splits=8, random_state=20)
kf_breast.get_n_splits(X_breast_)
# Out:
# 8

# %%
kf_ovarian = KFold(n_splits=8, random_state=20)
kf_ovarian.get_n_splits(X_ovarian_)
# Out:
# 8

# %%
kf_prostate = KFold(n_splits=8, random_state=20)
kf_prostate.get_n_splits(X_prostate_)
# Out:
# 8

# %% [markdown]
# **Random Forest with DWT**

# %% [markdown]
# - colon cancer

# %%
print(kf_colon)
scoring = []
for train_index, test_index in kf_colon.split(X_colon_):
    X_train, X_test = X_colon_[train_index], X_colon_[test_index]
    y_train, y_test = y_colon_[train_index], y_colon_[test_index]
    X_train_, y_test_ = standard_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_colon_std = np.array(scoring)
avg_rfg_std_colon = scoring_colon_std.mean()
print("avg accuraccy colon cancer = ",avg_rfg_std_colon)
print("max accuraccy colon cancer = ",scoring_colon_std.max())
print("min accuraccy colon cancer = ",scoring_colon_std.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  0.75
# Score in Random Forest :  0.625
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  0.875
# Score in Random Forest :  0.7142857142857143
# Score in Random Forest :  0.7142857142857143
# avg accuraccy colon cancer =  0.8348214285714286
# max accuraccy colon cancer =  1.0
# min accuraccy colon cancer =  0.625

# %%
print(kf_colon)
scoring = []
for train_index, test_index in kf_colon.split(X_colon_):
    X_train, X_test = X_colon_[train_index], X_colon_[test_index]
    y_train, y_test = y_colon_[train_index], y_colon_[test_index]
    X_train_, y_test_ = minmax_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_colon_mm = np.array(scoring)
avg_rfg_mm_colon = scoring_colon_mm.mean()
print("avg accuraccy colon cancer = ",avg_rfg_mm_colon)
print("max accuraccy colon cancer = ",scoring_colon_mm.max())
print("min accuraccy colon cancer = ",scoring_colon_mm.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  0.75
# Score in Random Forest :  0.75
# Score in Random Forest :  0.875
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  0.875
# Score in Random Forest :  0.5714285714285714
# Score in Random Forest :  0.8571428571428571
# avg accuraccy colon cancer =  0.8348214285714286
# max accuraccy colon cancer =  1.0
# min accuraccy colon cancer =  0.5714285714285714

# %% [markdown]
# - lung cancer

# %%
print(kf_lung)
scoring = []
for train_index, test_index in kf_lung.split(X_lung_):
    X_train, X_test = X_lung_[train_index], X_lung_[test_index]
    y_train, y_test = y_lung_[train_index], y_lung_[test_index]
    X_train_, y_test_ = standard_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_lung_std = np.array(scoring)
avg_rfg_std_lung = scoring_lung_std.mean()
print("avg accuraccy lung cancer = ",avg_rfg_std_lung)
print("max accuraccy lung cancer = ",scoring_lung_std.max())
print("min accuraccy lung cancer = ",scoring_lung_std.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  0.9565217391304348
# Score in Random Forest :  0.9565217391304348
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# avg accuraccy lung cancer =  0.9891304347826086
# max accuraccy lung cancer =  1.0
# min accuraccy lung cancer =  0.9565217391304348

# %%
print(kf_lung)
scoring = []
for train_index, test_index in kf_lung.split(X_lung_):
    X_train, X_test = X_lung_[train_index], X_lung_[test_index]
    y_train, y_test = y_lung_[train_index], y_lung_[test_index]
    X_train_, y_test_ = minmax_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_lung_mm = np.array(scoring)
avg_rfg_mm_lung = scoring_lung_mm.mean()
print("avg accuraccy lung cancer = ",avg_rfg_mm_lung)
print("max accuraccy lung cancer = ",scoring_lung_mm.max())
print("min accuraccy lung cancer = ",scoring_lung_mm.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  0.9565217391304348
# Score in Random Forest :  0.9565217391304348
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# avg accuraccy lung cancer =  0.9891304347826086
# max accuraccy lung cancer =  1.0
# min accuraccy lung cancer =  0.9565217391304348

# %% [markdown]
# - central nervous system

# %%
print(kf_cns)
scoring = []
for train_index, test_index in kf_cns.split(X_cns_):
    X_train, X_test = X_cns_[train_index], X_cns_[test_index]
    y_train, y_test = y_cns_[train_index], y_cns_[test_index]
    X_train_, y_test_ = standard_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_cns_std = np.array(scoring)
avg_rfg_std_cns = scoring_cns_std.mean()
print("avg accuraccy central nervous system = ",avg_rfg_std_cns)
print("max accuraccy central nervous system = ",scoring_cns_std.max())
print("min accuraccy central nervous system = ",scoring_cns_std.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  0.0
# Score in Random Forest :  0.0
# Score in Random Forest :  0.375
# Score in Random Forest :  0.875
# Score in Random Forest :  0.5714285714285714
# Score in Random Forest :  0.7142857142857143
# Score in Random Forest :  1.0
# Score in Random Forest :  0.5714285714285714
# avg accuraccy central nervous system =  0.5133928571428571
# max accuraccy central nervous system =  1.0
# min accuraccy central nervous system =  0.0

# %%
print(kf_cns)
scoring = []
for train_index, test_index in kf_cns.split(X_cns_):
    X_train, X_test = X_cns_[train_index], X_cns_[test_index]
    y_train, y_test = y_cns_[train_index], y_cns_[test_index]
    X_train_, y_test_ = minmax_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_cns_mm = np.array(scoring)
avg_rfg_mm_cns = scoring_cns_mm.mean()
print("avg accuraccy central nervous system = ",avg_rfg_mm_cns)
print("max accuraccy central nervous system = ",scoring_cns_mm.max())
print("min accuraccy central nervous system = ",scoring_cns_mm.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  0.0
# Score in Random Forest :  0.0
# Score in Random Forest :  0.375
# Score in Random Forest :  1.0
# Score in Random Forest :  0.5714285714285714
# Score in Random Forest :  1.0
# Score in Random Forest :  0.7142857142857143
# Score in Random Forest :  0.7142857142857143
# avg accuraccy central nervous system =  0.546875
# max accuraccy central nervous system =  1.0
# min accuraccy central nervous system =  0.0

# %% [markdown]
# - breast cancer

# %%
print(kf_breast)
scoring = []
for train_index, test_index in kf_breast.split(X_breast_):
    X_train, X_test = X_breast_[train_index], X_breast_[test_index]
    y_train, y_test = y_breast_[train_index], y_breast_[test_index]
    X_train_, y_test_ = standard_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_breast_std = np.array(scoring)
avg_rfg_std_breast = scoring_breast_std.mean()
print("avg accuraccy breast cancer = ",avg_rfg_std_breast)
print("max accuraccy breast cancer = ",scoring_breast_std.max())
print("min accuraccy breast cancer = ",scoring_breast_std.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  0.15384615384615385
# Score in Random Forest :  0.25
# Score in Random Forest :  0.5833333333333334
# Score in Random Forest :  0.5
# Score in Random Forest :  0.8333333333333334
# Score in Random Forest :  0.6666666666666666
# Score in Random Forest :  0.5
# Score in Random Forest :  0.6666666666666666
# avg accuraccy breast cancer =  0.5192307692307692
# max accuraccy breast cancer =  0.8333333333333334
# min accuraccy breast cancer =  0.15384615384615385

# %%
print(kf_breast)
scoring = []
for train_index, test_index in kf_breast.split(X_breast_):
    X_train, X_test = X_breast_[train_index], X_breast_[test_index]
    y_train, y_test = y_breast_[train_index], y_breast_[test_index]
    X_train_, y_test_ = minmax_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_breast_mm = np.array(scoring)
avg_rfg_mm_breast = scoring_breast_mm.mean()
print("avg accuraccy breast cancer = ",avg_rfg_mm_breast)
print("max accuraccy breast cancer = ",scoring_breast_mm.max())
print("min accuraccy breast cancer = ",scoring_breast_mm.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  0.3076923076923077
# Score in Random Forest :  0.25
# Score in Random Forest :  0.5
# Score in Random Forest :  0.5
# Score in Random Forest :  0.6666666666666666
# Score in Random Forest :  0.75
# Score in Random Forest :  0.5833333333333334
# Score in Random Forest :  0.5
# avg accuraccy breast cancer =  0.5072115384615384
# max accuraccy breast cancer =  0.75
# min accuraccy breast cancer =  0.25

# %% [markdown]
# - ovarian cancer

# %%
print(kf_ovarian)
scoring = []
for train_index, test_index in kf_ovarian.split(X_ovarian_):
    X_train, X_test = X_ovarian_[train_index], X_ovarian_[test_index]
    y_train, y_test = y_ovarian_[train_index], y_ovarian_[test_index]
    X_train_, y_test_ = standard_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_ovarian_std = np.array(scoring)
avg_rfg_std_ovarian = scoring_ovarian_std.mean()
print("avg accuraccy ovarian = ",avg_rfg_std_ovarian)
print("max accuraccy ovarian = ",scoring_ovarian_std.max())
print("min accuraccy ovarian = ",scoring_ovarian_std.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  1.0
# Score in Random Forest :  0.96875
# Score in Random Forest :  0.96875
# Score in Random Forest :  0.96875
# Score in Random Forest :  1.0
# Score in Random Forest :  0.967741935483871
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# avg accuraccy ovarian =  0.9842489919354839
# max accuraccy ovarian =  1.0
# min accuraccy ovarian =  0.967741935483871

# %%
print(kf_ovarian)
scoring = []
for train_index, test_index in kf_ovarian.split(X_ovarian_):
    X_train, X_test = X_ovarian_[train_index], X_ovarian_[test_index]
    y_train, y_test = y_ovarian_[train_index], y_ovarian_[test_index]
    X_train_, y_test_ = minmax_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_ovarian_mm = np.array(scoring)
avg_rfg_mm_ovarian = scoring_ovarian_mm.mean()
print("avg accuraccy ovarian = ",avg_rfg_mm_ovarian)
print("max accuraccy ovarian = ",scoring_ovarian_mm.max())
print("min accuraccy ovarian = ",scoring_ovarian_mm.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  1.0
# Score in Random Forest :  0.9375
# Score in Random Forest :  0.96875
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# avg accuraccy ovarian =  0.98828125
# max accuraccy ovarian =  1.0
# min accuraccy ovarian =  0.9375

# %% [markdown]
# - prostate

# %%
print(kf_prostate)
scoring = []
for train_index, test_index in kf_prostate.split(X_prostate_):
    X_train, X_test = X_prostate_[train_index], X_prostate_[test_index]
    y_train, y_test = y_prostate_[train_index], y_prostate_[test_index]
    X_train_, y_test_ = standard_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_prostate_std = np.array(scoring)
avg_rfg_std_prostate = scoring_prostate_std.mean()
print("avg accuraccy prostate = ",avg_rfg_std_prostate)
print("max accuraccy prostate = ",scoring_prostate_std.max())
print("min accuraccy prostate = ",scoring_prostate_std.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  0.0
# Score in Random Forest :  0.0
# Score in Random Forest :  0.3333333333333333
# Score in Random Forest :  0.6666666666666666
# Score in Random Forest :  0.6666666666666666
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  0.5
# avg accuraccy prostate =  0.5208333333333333
# max accuraccy prostate =  1.0
# min accuraccy prostate =  0.0

# %%
print(kf_prostate)
scoring = []
for train_index, test_index in kf_prostate.split(X_prostate_):
    X_train, X_test = X_prostate_[train_index], X_prostate_[test_index]
    y_train, y_test = y_prostate_[train_index], y_prostate_[test_index]
    X_train_, y_test_ = minmax_scaler(X_train, X_test)
    train_coef, test_coef = dwt(X_train, X_test)
    (train_cA, train_cD) = koef_train(train_coef)
    (test_cA, test_cD) = koef_test(test_coef)
    model_rfg.fit(train_cA,y_train)
    pred = model_rfg.predict(test_cA)
    hasil = accuracy_score(y_test, pred)
    print("Score in Random Forest : ", hasil)
    scoring.append(hasil)
scoring_prostate_mm = np.array(scoring)
avg_rfg_mm_prostate = scoring_prostate_mm.mean()
print("avg accuraccy prostate = ",avg_rfg_mm_prostate)
print("max accuraccy prostate = ",scoring_prostate_mm.max())
print("min accuraccy prostate = ",scoring_prostate_mm.min())
# Out:
# KFold(n_splits=8, random_state=20, shuffle=False)
# Score in Random Forest :  0.3333333333333333
# Score in Random Forest :  0.0
# Score in Random Forest :  0.3333333333333333
# Score in Random Forest :  0.6666666666666666
# Score in Random Forest :  0.6666666666666666
# Score in Random Forest :  1.0
# Score in Random Forest :  1.0
# Score in Random Forest :  0.5
# avg accuraccy prostate =  0.5625
# max accuraccy prostate =  1.0
# min accuraccy prostate =  0.0

# %% [markdown]
# ### Result

# %%
hasil = pd.DataFrame({
    "dataset" : ['colon cancer', 'lung cancer', 'central nervous system', 'breast cancer', 'ovarian cancer', 'prostate cancer'],
    "Akurasi (standard scaler)" : [avg_rfg_std_colon,avg_rfg_std_lung,avg_rfg_std_cns,avg_rfg_std_breast,avg_rfg_std_ovarian,avg_rfg_std_prostate],
    "Akurasi (minmax scaler)" : [avg_rfg_mm_colon,avg_rfg_mm_lung,avg_rfg_mm_cns,avg_rfg_mm_breast,avg_rfg_mm_ovarian,avg_rfg_mm_prostate]
})

hasil = hasil.set_index(['dataset'],drop=True)
hasil
# Out:
#                         Akurasi (standard scaler)  Akurasi (minmax scaler)
# dataset
# colon cancer                             0.834821                 0.834821
# lung cancer                              0.989130                 0.989130
# central nervous system                   0.513393                 0.546875
# breast cancer                            0.519231                 0.507212
# ovarian cancer                           0.984249                 0.988281
# prostate cancer                          0.520833                 0.562500

# %%
hasil.loc[:,['Akurasi (standard scaler)','Akurasi (minmax scaler)']].plot.bar(color=['red','blue'], figsize=(20,10))
plt.title("Perbandingan Akurasi")
plt.xlabel('Dataset')
plt.ylabel('Akurasi')
plt.show()
